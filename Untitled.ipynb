# %%
import pandas as pd

# Load dataset
df = pd.read_csv('loan_data.csv')

# Display first few rows
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
cat_cols = ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']

for col in cat_cols:
    print(col)
    print(df[col].unique())
# Out:
# person_gender
# ['female' 'male']
# person_education
# ['Master' 'High School' 'Bachelor' 'Associate' 'Doctorate']
# person_home_ownership
# ['RENT' 'OWN' 'MORTGAGE' 'OTHER']
# loan_intent
# ['PERSONAL' 'EDUCATION' 'MEDICAL' 'VENTURE' 'HOMEIMPROVEMENT'
#  'DEBTCONSOLIDATION']
# previous_loan_defaults_on_file
# ['No' 'Yes']

# %% [raw]
# set person_gender to false when female is selected
# set 'Master' 'High School' 'Bachelor' 'Doctorate' to false when 'Associate' is selected
# set 'RENT' 'OWN' 'OTHER' to false when MORTGAGE is selected
# set 'PERSONAL' 'EDUCATION' 'MEDICAL' 'VENTURE' 'HOMEIMPROVEMENT' to false when 'DEBTCONSOLIDATION' is selected
# set 'Yes' to false when No is selected
